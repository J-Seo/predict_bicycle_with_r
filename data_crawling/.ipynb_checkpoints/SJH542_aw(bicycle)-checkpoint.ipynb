# %%
# Use BeautifulSoup package for text mining  
from bs4 import BeautifulSoup
# Load the web-site url
from urllib import request
import requests
import time
import datetime

# %%
# 기상청 기온 
def crawl_temp(month, day):
    t = 1 
    temp_dict = dict()
    if day < 10: 
        url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t11&x=0&y=0&reg=109&tm=2018.0{}.0{}.00%3A00'.format(month, day)
    else:
        url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t11&x=0&y=0&reg=109&tm=2018.0{}.{}.00%3A00'.format(month, day)
    bs4 = requests.get(url)
    
    # BS4를 통해서 제목 및 내용 가져오기
    #html = bs4.read
    #if req.ok:
    html = bs4.text
    #print(html)
    weather = BeautifulSoup(html, 'html.parser')
        
    tds = weather.find_all('tr')[4].find_all('td')
    
    print(tds[0].text) # 서울이 맞는지 체크
    
    for td in tds[1:]:
        temp_dict[t] = float(td.text)
        t += 1 
        
    return temp_dict

# %%
# 기상청 상대습도
def crawl_hum(month, day):
    t = 1 
    hum_dict = dict()
    if day < 10: 
        url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t13&reg=109&tm=2018.0{}.0{}.00%3A00&x=14&y=14'.format(month, day)
    else:
        url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t13&reg=109&tm=2018.0{}.{}.00%3A00&x=14&y=14'.format(month, day)
    bs4 = requests.get(url)
    
    # BS4를 통해서 제목 및 내용 가져오기
    #html = bs4.read
    #if req.ok:
    html = bs4.text
    #print(html)
    weather = BeautifulSoup(html, 'html.parser')
        
    tds = weather.find_all('tr')[4].find_all('td')
    
    print(tds[0].text) # 서울이 맞는지 체크
    
    for td in tds[1:]:
        hum_dict[t] = int(td.text)
        t += 1
        hum_dict[t] = int(td.text)
        t += 1
        hum_dict[t] = int(td.text)
        t += 1
        
    return hum_dict

# %%
# 기상청 풍속
def crawl_wind(month, day):
    t = 1 
    wind_dict = dict()
    if day < 10: 
        url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t02&reg=109&tm=2018.0{}.0{}.00%3A00&x=29&y=10'.format(month, day)
    else:
        url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t02&reg=109&tm=2018.0{}.{}.00%3A00&x=29&y=10'.format(month, day)
    bs4 = requests.get(url)
    
    # BS4를 통해서 제목 및 내용 가져오기
    #html = bs4.read
    #if req.ok:
    html = bs4.text
    #print(html)
    weather = BeautifulSoup(html, 'html.parser')
        
    tds = weather.find_all('tr')[4].find_all('td')
    
    print(tds[0].text) # 서울이 맞는지 체크
    
    for td in tds[1:]:
        wind_dict[t] = float(td.text)
        t += 1
        
    return wind_dict

# %%
data_wind = list()
mth = [1,2]
for m in mth:
    
    if m%2 == 1:
        end_day = 31        
    else:
        end_day = 30
    
    for d in range(1,end_day+1):
        data_wind.append(crawl_wind(m,d))
# Out:
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ba875d8e0801> in <module>
#       9
#      10     for d in range(1,end_day+1):
# ---> 11         data_wind.append(crawl_wind(m,d))
#
# <ipython-input-4-4ee2eba35fb4> in crawl_wind(month, day)
#       7     else:
#       8         url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t02&reg=109&tm=2018.0{}.{}.00%3A00&x=29&y=10'.format(month, day)
# ----> 9     bs4 = requests.get(url)
#      10
#      11     # BS4를 통해서 제목 및 내용 가져오기
#
# ~/anaconda3/envs/jaehyung37/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ...

# %%
c = list()
for d in data_wind:
    c = c + d 

df = pd.DataFrame({'wind': c})
df.to_csv('wind.csv', index = False, encoding = 'utf-8', header = True, sep = ',')

# %%
# 기상청 종합 정보
def crawl_total(month, day, hour):
    total_dict = dict()
    if day < 10:
        if hour < 10: 
            url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t99&reg=109&tm=2018.0{}.0{}.0{}%3A00&x=11&y=10'.format(month, day, hour)
        else:
            url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t99&reg=109&tm=2018.0{}.0{}.{}%3A00&x=11&y=10'.format(month, day, hour)
    else:
        if hour < 10:
            url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t99&reg=109&tm=2018.0{}.{}.0{}%3A00&x=11&y=10'.format(month, day, hour)
        else:
            url = 'http://www.weather.go.kr/weather/observation/currentweather.jsp?auto_man=m&type=t99&reg=109&tm=2018.0{}.{}.{}%3A00&x=11&y=10'.format(month, day, hour)
    
    bs4 = requests.get(url)
    
    # BS4를 통해서 제목 및 내용 가져오기
    #html = bs4.read
    #if req.ok:
    html = bs4.text
    #print(html)
    weather = BeautifulSoup(html, 'html.parser')
        
    tds = weather.find_all('tr')[5].find_all('td')
    
    print(tds[0].text) # 서울이 맞는지 체크
    
    
    # 날짜
    if day < 10:
        total_dict['date'] = '2018-0{}-0{}'.format(month, day)
    else:
        total_dict['date'] = '2018-0{}-{}'.format(month, day)
        
    
    # 계절
    total_dict['season'] = 1
    
    # 연도
    total_dict['year'] = 0
    
    # 달
    total_dict['month'] =  month
    
    # 시간
    total_dict['hour'] = hour
    
    # 요일 (0: 월 ~ 6: 일)
    total_dict['week'] = datetime.datetime(2018,month,day).weekday()
    
    # 주말 여부
    if datetime.datetime(2018,month,day).weekday() == (5 or 6):
        total_dict['workingday'] = 0
    else:
        total_dict['workingday'] = 1
    
    
    # 현재 일기
    condition = tds[1].text
    if condition == ('맑음' or '구름 조금'):
        total_dict['condition'] = 1
    
    elif condition == ('구름 많음' or '연무' or '박무' or '흐림'):
        total_dict['condition'] = 2
        
    elif condition == ('약한눈단속' or '눈 끝남' or '약한눈계속' or '약한비단속' or '약한비계속' or '비 끝남' or '이슬비 끝'):
        total_dict['condition'] = 3
    
    elif condition == ('보통눈단속' or '보통눈계속' or '보통비단속' or '보통비계속'):
        total_dict['condition'] = 4
    
    else:
        total_dict['condition'] = 'NA'
    
    # 실제 온도
    temp = float(tds[5].text)
    total_dict['temp'] = temp
    
    # 이슬점 온도
    htemp = float(tds[6].text)
    total_dict['htemp'] = htemp
    
    # 체감 온도
    atemp = float(tds[7].text)
    total_dict['atemp'] = atemp
    
    # 상대 습도
    hum = int(tds[10].text)
    total_dict['hum'] =  hum
    
    # 풍속
    wind = 'NA'
    total_dict['wind'] = wind
    
    # 총 대여횟수
    cnt = 'NA'
    total_dict['cnt'] = cnt

    return total_dict

# %%
dataset = list()
mth = [1,2]
for m in mth:
    
    if m%2 == 1:
        end_day = 31        
    else:
        end_day = 30
    
    for d in range(1,end_day+1):
        
        for h in range(1,25):
        
            dataset.append(crawl_total(m,d,h))
# Out:
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# 서울
# ...

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(dataset)
df
# Out:
#             date  season  year  month  hour  week  workingday condition  temp  \
# 0     2018-01-01       1     0      1     1     0           1        NA  -3.3
# 1     2018-01-01       1     0      1     2     0           1         1  -3.7
# 2     2018-01-01       1     0      1     3     0           1         1  -4.0
# 3     2018-01-01       1     0      1     4     0           1         1  -4.2
# 4     2018-01-01       1     0      1     5     0           1         1  -4.4
# ...          ...     ...   ...    ...   ...   ...         ...       ...   ...
# 1411  2018-02-28       1     0      2    20     2           1        NA   2.7
# 1412  2018-02-28       1     0      2    21     2           1        NA   2.4
# 1413  2018-02-28       1     0      2    22     2           1        NA   2.3
# 1414  2018-02-28       1     0      2    23     2           1        NA   1.8
# 1415  2018-02-28       1     0      2    24     2           1        NA   2.0
#
#       htemp  atemp  hum wind cnt
# ...

# %%
df.to_csv('SJH542_(bicycle)d.csv', index = False, encoding = 'utf-8', header = True, sep = ',')
